# %%
import numpy as np
import skimage 
image = skimage.data.astronaut()
skimage.io.imshow(image)
skimage.io.show()

# %%
import numpy as np
import skimage 
image = skimage.data.astronaut()
image[0:600,0:25]=[0,0,0]
image[0:600,490:600]=[0,0,0]
image[0:25,0:600]=[0,0,0]
image[490:600,0:600]=[0,0,0]

skimage.io.imshow(image)
skimage.io.show()

# %%
import numpy as np
import skimage 
image = skimage.data.astronaut()
cropped = image[20:180,150:300]
skimage.io.imshow(cropped)
skimage.io.show()

# %%
import numpy as np
import skimage 
image = skimage.data.astronaut()
cropped = image[85:115,190:215]
skimage.io.imshow(cropped)
skimage.io.show()

# %%
import numpy as np
import skimage 
image = skimage.data.astronaut()
cropped = image[85:115,190:215]
cropped[14:16,12:15]=[0,0,0]
cropped[15:17,12:14]=[255,0,0]
skimage.io.imshow(cropped)
skimage.io.show()

# %%
import numpy as np
import skimage 
image = skimage.data.astronaut()

#left
image[100:400,50:70]=[255,0,255]
image[100:400,140:160]=[255,0,255]

image[100:400,300:320]=[255,0,255]
image[100:400,390:410]=[255,0,255]

#Top
image[100:120,50:160]=[255,0,255]
image[200:220,50:160]=[255,0,255]

image[100:120,300:410]=[255,0,255]
image[200:220,300:410]=[255,0,255]



#bottom
#image[490:600,0:600]=[255,255,255]

skimage.io.imshow(image)
skimage.io.show()

# %%
import numpy as np
import skimage 
from skimage.color import rgb2gray
original = skimage.data.cat()
grayscale = rgb2gray(original)
skimage.io.imshow(grayscale)
skimage.io.show()

# %%
import numpy as np
import skimage 
from skimage.transform import rotate
original = skimage.data.cat()
turn = rotate(original, angle=180)
skimage.io.imshow(turn)
skimage.io.show()
